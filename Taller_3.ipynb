# %% [markdown]
# <a href="https://colab.research.google.com/github/jcmoralest/ICESI_AalisisDatos1_PSmart/blob/main/Taller_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Cargar el dataset
df = pd.read_csv('datos_buro_T3.csv')

df = pd.DataFrame(data)

df.head(5000)
# Out:
#       Edad     Género  Ingreso_mensual  Saldo_total  Número_de_cuentas  \
# 0       63   Femenino          1995089      9864628                  5
# 1       53   Femenino          4063724      4092912                  4
# 2       23   Femenino          5210231     18200066                  4
# 3       22   Femenino          9404231      6860855                  1
# 4       54   Femenino          7025897     13744270                  1
# ...    ...        ...              ...          ...                ...
# 4995    63   Femenino           696129     11440870                  8
# 4996    68   Femenino          4113865      4381028                  4
# 4997    25  Masculino          9286533      3945280                  6
# 4998    54  Masculino          4470369     10336483                  1
# 4999    43   Femenino          6622189     17174947                  8
#
#       Historial_crediticio Tipo_de_empleo  Porcentaje_uso_credito  \
# ...

# %%
# Mapa de calor de correlaciones
from sklearn.preprocessing import LabelEncoder

# Copia del dataframe original
df_encoded = df.copy()

# Codificar variables categóricas con Label Encoding
label_cols = ['Género', 'Tipo_de_empleo', 'Mora_en_pagos']
label_encoders = {}

for col in label_cols:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col])
    label_encoders[col] = le

# Calcular la matriz de correlación incluyendo las columnas codificadas
corr_matrix = df_encoded.corr()

# Visualizar el mapa de calor de correlaciones
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Mapa de Calor de Correlaciones incluyendo Variables Categóricas')
plt.show()

# %%
sns.scatterplot(x='Edad', y='Puntaje_crediticio', data=df)
plt.title('Puntaje Crediticio vs. Edad')
plt.show()

# %%
#Puntaje Crediticio vs. Ingreso Mensual
sns.scatterplot(x='Ingreso_mensual', y='Puntaje_crediticio', data=df)
plt.title('Puntaje Crediticio vs. Ingreso Mensual')
plt.show()

# %%
#Puntaje Crediticio vs. Mora en Pagos (Categórico)
sns.boxplot(x='Mora_en_pagos', y='Puntaje_crediticio', data=df)
plt.title('Puntaje Crediticio vs. Mora en Pagos')
plt.show()

# %%
#1 Variables Numéricas: Del análisis de correlación, podríamos concluir que variables como el saldo total, el ingreso mensual, y el porcentaje de uso de crédito
#tienen una correlación significativa con el puntaje crediticio. Esto sugiere que las personas con mayores ingresos y menores saldos tienden a tener un mejor puntaje.

#2 Variables Categóricas: En el análisis bivariado, se podría observar que aquellos que han estado en mora en pagos tienen un puntaje significativamente más bajo,
#lo que indica que la mora en pagos es una variable crítica para el puntaje crediticio.

#3 Edad y Historial Crediticio: Aunque la edad puede tener alguna relación con el puntaje, es probable que el historial crediticio sea un predictor más fuerte,
#dado que un historial más largo puede indicar mayor experiencia en el manejo de crédito.
